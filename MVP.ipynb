# %%
#Install the necessary packages
import sys
# !{sys.executable} -m pip install ipython-sql
# !{sys.executable} -m pip install sqlalchemy
# !{sys.executable} -m pip install psycopg2-binary
# !{sys.executable} -m pip install pandas
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: ipython-sql in /usr/local/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/local/lib/python3.8/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /usr/local/lib/python3.8/site-packages (from ipython-sql) (1.4.31)
# Requirement already satisfied: prettytable<1 in /usr/local/lib/python3.8/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: ipython>=1.0 in /usr/local/lib/python3.8/site-packages (from ipython-sql) (8.1.0)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.8/site-packages (from ipython-sql) (0.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: appnope in /usr/local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (3.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (57.4.0)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (2.8.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.18.0)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.1.2)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.8/site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.2.2)
# Requirement already satisfied: executing in /usr/local/lib/python3.8/site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.8.2)
# Requirement already satisfied: asttokens in /usr/local/lib/python3.8/site-packages (from stack-data->ipython>=1.0->ipython-sql) (2.0.5)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.8/site-packages (1.4.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/site-packages (from sqlalchemy) (1.1.2)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.8/site-packages (2.9.3)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.8/site-packages (from pandas) (1.20.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621

# %%
# %load_ext sql
from sqlalchemy import create_engine
import pandas as pd
# %sql postgresql://user:FakePasswordHere@localhost:5432/db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
engine = create_engine('postgresql://user:FakePasswordHere@localhost:5432/db')

# %%
df = pd.read_sql('SELECT * FROM users LIMIT 55', engine)
df
# Out:
#     id                                              value  \
# 0    1  Sebastien Hillaire <Sebastien.Hillaire@epicgam...
# 1    2  sebastien hillaire <Sebastien.Hillaire@epicgam...
# 2    3      Martin Ridgers <Martin.Ridgers@epicgames.com>
# 3    6  Andrey Yamashev <andrey.yamashev@xa.epicgames....
# 4    5             buildmachine <unrealbot@epicgames.com>
# 5   17              helen yang <helen.yang@epicgames.com>
# 6   23          devon penney <Devon.Penney@epicgames.com>
# 7   42    cedric caillaud <cedric.caillaud@epicgames.com>
# 8   24          jason stasik <Jason.Stasik@epicgames.com>
# 9   25  aditya ravichandran <aditya.ravichandran@epicg...
# 10  29          luc eygasier <luc.eygasier@epicgames.com>
# 11  39             patrick hardy <patrick@geodesic.games>
# 12  59      vincent robert <vincent.robert@epicgames.com>
# 13  83          zach rammell <zach.rammell@epicgames.com>
# 14  86      brandon dawson <brandon.dawson@epicgames.com>
# 15  50        charles bloom <charles.bloom@epicgames.com>
# 16   8            stu mckenna <Stu.McKenna@epicgames.com>
# 17   9        eric mcdaniel <Eric.Mcdaniel@epicgames.com>
# 18  22        jimmy andrews <Jimmy.Andrews@epicgames.com>
# 19  10                dan smith <dan.smith@epicgames.com>
# 20  11            daren cheng <daren.cheng@epicgames.com>
# 21  12        aaron mcleran <Aaron.McLeran@epicgames.com>
# 22  13          richard malo <Richard.Malo@epicgames.com>
# 23  14      benn gallagher <Benn.Gallagher@epicgames.com>
# 24  28      brice criswell <Brice.Criswell@epicgames.com>
# 25  15      michael noland <michael.noland@epicgames.com>
# 26  16        zousar shaker <zousar.shaker@epicgames.com>
# 27  18    francis hurteau <Francis.Hurteau@epicgames.com>
# 28  19  charles lefebvre <charles.lefebvre@epicgames.com>
# 29  20        patrick kelly <Patrick.Kelly@epicgames.com>
# 30  21                    rob gay <Rob.Gay@epicgames.com>
